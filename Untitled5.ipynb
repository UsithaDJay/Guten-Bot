# %%
pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ...

# %%
pip install openai;
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
# !pip install --upgrade langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade langchain

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 46.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 116.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.8 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import GutenbergLoader
loader = GutenbergLoader("https://www.gutenberg.org/files/71353/71353-0.txt")
data = loader.load_and_split()
data
# Out:
# [Document(page_content='The Project Gutenberg eBook of The four Corners in California\r\n\n\n\r\n\n\nThis ebook is for the use of anyone anywhere in the United States and \r\n\n\nmost other parts of the world at no cost and with almost no restrictions \r\n\n\nwhatsoever. You may copy it, give it away or re-use it under the terms \r\n\n\nof the Project Gutenberg License included with this ebook or online \r\n\n\nat www.gutenberg.org. If you are not located in the United States, \r\n\n\nyou will have to check the laws of the country where you are located \r\n\n\nbefore using this eBook.\r\n\n\n\r\n\n\n\r\n\n\nTitle: The four Corners in California\r\n\n\n\r\n\n\nAuthor: Amy E. Blanchard\r\n\n\n\r\n\n\nRelease Date: August 6, 2023 [eBook #71353]\r\n\n\n\r\n\n\nLanguage: English\r\n\n\n\r\n\n\nCredits: David Edwards, Mary Meehan and the Online Distributed\r\n\n\n         Proofreading Team at https://www.pgdp.net\r\n\n\n\r\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK THE FOUR CORNERS IN C
# ...

# %%
import requests
from bs4 import BeautifulSoup
import difflib

# Function to search for a book by name and return the best match URL
def search_book_by_name(book_name):
    base_url = "https://www.gutenberg.org/"
    search_url = base_url + "ebooks/search/?query=" + book_name.replace(" ", "+") + "&submit_search=Go%21"

    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the best match link based on similarity ratio
    best_match_ratio = 0
    best_match_url = ""

    for link in soup.find_all("li", class_="booklink"):
        link_title = link.find("span", class_="title").get_text()
        similarity_ratio = difflib.SequenceMatcher(None, book_name.lower(), link_title.lower()).ratio()
        if similarity_ratio > best_match_ratio:
            best_match_ratio = similarity_ratio
            best_match_url = base_url + link.find("a").get("href")

    return best_match_url
def get_plain_text_link(book_url):
    response = requests.get(book_url)
    soup = BeautifulSoup(response.content, "html.parser")

    plain_text_link = ""

    for row in soup.find_all("tr"):
        format_cell = row.find("td", class_="unpadded icon_save")
        if format_cell and "Plain Text UTF-8" in format_cell.get_text():
            plain_text_link = format_cell.find("a").get("href")
            break

    return plain_text_link


# Function to get the content of the "Plain Text UTF-8" link
def get_plain_text_content(plain_text_link):
    response = requests.get(plain_text_link)
    content = response.text
    return content

book_name = input("Enter the name of the book: ")
best_match_url = search_book_by_name(book_name)

if best_match_url:
    plain_text_link = get_plain_text_link(best_match_url)
    if plain_text_link:
        full_plain_text_link = "https://www.gutenberg.org" + plain_text_link
        plain_text_content = get_plain_text_content(full_plain_text_link)
        print("Plain Text UTF-8 content:", plain_text_content)
    else:
        print("No Plain Text UTF-8 link found.")
else:
    print("No matching book found.")
# Out:
# Streaming output truncated to the last 5000 lines.
# “This will be a regularly merry Christmas to me, with presents in the
# morning, you and letters in the afternoon, and a party at night,” said
# Amy, as they alighted among the ruins of the old fort, and a flock of
# splendid peacocks came trooping about them, tamely waiting to be fed.
# While Amy stood laughing on the bank above him as she scattered crumbs
# to the brilliant birds, Laurie looked at her as she had looked at him,
# with a natural curiosity to see what changes time and absence had
# wrought. He found nothing to perplex or disappoint, much to admire and
# approve, for overlooking a few little affectations of speech and
# manner, she was as sprightly and graceful as ever, with the addition of
# that indescribable something in dress and bearing which we call
# elegance. Always mature for her age, she had gained a certain aplomb in
# both carriage and conversation, which made her seem more of a woman of
# ...

# %%
import re




start_marker_pattern = re.compile(r"\*\*\* START OF (?:THE )?PROJECT GUTENBERG EBOOK .* \*\*\*")
end_marker_pattern = re.compile(r"\*\*\* END OF (?:THE )?PROJECT GUTENBERG EBOOK .* \*\*\*")


start_match = start_marker_pattern.search(plain_text_content)
end_match = end_marker_pattern.search(plain_text_content)

if start_match and end_match:

    main_content = plain_text_content[start_match.end():end_match.start()]


    new_plain_text_content = main_content
else:
    # Handle the case when markers are not found
    new_plain_text_content = "Markers not found."

# Now, you can use new_plain_text_content for summarization

# %%
plain_text_content=new_plain_text_content

# %%
pip install textsum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=0fd50052ce9f4d68a95a448ab69f61e798c1bea727d66a2fbfbc5074e7824b66
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=7843898ecacb32d8e0ba89a76c67c7f836464099648614d06fdcc0c9ea976790
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built fire emoji
# ...

# %%
from textsum.summarize import Summarizer

model_name = "pszemraj/led-large-book-summary"
summarizer = Summarizer(
    model_name_or_path=model_name,
    token_batch_length=10000,
)
# Out:
# WARNING:root:Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# ...

# %%
min_word_count = 200
max_word_count = 300


tokens_per_word = 1

min_token_count = min_word_count * tokens_per_word
max_token_count = max_word_count * tokens_per_word

# Set the length constraints in the inference params
inference_params = summarizer.inference_params
inference_params['max_length'] = int(max_token_count)
inference_params['min_length'] = int(min_token_count)

# Apply the updated inference params
summarizer.set_inference_params(inference_params)

# %%
out_str = summarizer.summarize_string(plain_text_content)

print(f"summary: {out_str}")
# Out:
# Generating Summaries:   0%|          | 0/31 [00:00<?, ?it/s]
# ...

# %%
long_text = out_str



sentences = long_text.split(". ")

# Calculate the number of sentences needed for the middle part
middle_sentences_count = min(len(sentences) - 2, 5)  # Adjust the number as needed

# Extract the first, middle, and last sentences
first_sentence = sentences[0]
middle_sentences = ". ".join(sentences[1:middle_sentences_count + 1])
last_sentence = sentences[-1]

# Calculate the number of words needed for the middle part
max_words = 300 - (len(first_sentence.split()) + len(last_sentence.split()))

# Truncate the middle part to fit within the word limit
middle_sentences = " ".join(middle_sentences.split()[:max_words])

# Combine the sentences into a 300-word paragraph
summary_paragraph = f"{first_sentence}. {middle_sentences}. {last_sentence}"

# Print or use the summary paragraph
print("Summary Paragraph (300 words):", summary_paragraph)
# Out:
# Summary Paragraph (300 words): The story of Little Women begins in the home of the March family. The four March daughters Meg, Jo, Beth, and the youngest Amy are gathered together in the living room. They are discussing the upcoming Christmas along with their Mother who is upstairs collecting clothes for the family. As the clock strikes six, the girls each pick out a pair of slippers to give to their poor friend Marmee while her husband is away. They then discuss what they will buy for themselves for Christmas and decide to do so rather than spend money on presents for their mother. After the girls have finished their shopping, they all prepare for Christmas breakfast where they will give bread and milk to their neighbor, the Hummel family. March has a talk with her daughters, and Jo confesses that her castle is not as complete as she had planned, but she would not change it

# %%
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-31-a262714e90ec> in <cell line: 24>()
#      22
#      23 # Generate the summary
# ---> 24 summary = summarize_with_gpt3(out_str)
#      25
#      26 # Print or use the 'summary' variable as needed
#
# <ipython-input-31-a262714e90ec> in summarize_with_gpt3(text, max_tokens)
#       8     summaries = []
#       9     for segment in segments:
# ---> 10         response = openai.Completion.create(
#      11             engine="text-davinci-002",
#      12             prompt="Summarize the following text:\n" + segment,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...
